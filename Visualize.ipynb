# %%
from matplotlib import pyplot as p
import numpy as np

# %%
x = np.array([10,20])
y = np.array([30,40])

# %%
p.plot(x,y)

# %%
#marker = 'o' : It means alphabet "o" is not zero 0 
p.plot(x,y,marker = 'o')

# %%
a = np.array([10,20,30,40,50,60])
b = np.array([100,200,300,400])

# %%
p.plot(b,"o")

# %%
p.plot(b)

# %%
p.plot(x,y,'p--r')

# %%
p.plot(x,y,'p--r',ms = 20,)

# %%
p.plot(x,y,"p--r",ms = 10, mfc = "k")

# %%
#linestyle
p.plot(x,y,linestyle = "dashed", ms = 50,marker = 's',mfc = "blue",mec = 'red' ,c = 'orange')
