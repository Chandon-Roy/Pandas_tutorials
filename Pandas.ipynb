# %% [markdown]
# **[www.ybifoundation.org](https://www.ybifoundation.org/)**
#
# [Join Live QnA Session to Ask Doubts](https://www.ybifoundation.org/session/live-qna-session)

# %% [markdown]
# # **Introduction**

# %% [markdown]
# Python Pandas is an open-source data manipulation and analysis library that provides versatile and powerful tools for working with structured data. It is built on top of the NumPy library and is widely used in data science, data analysis, and data engineering tasks.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Pandas series** is a one-dimensional array that contains elements of the same data type. Series are mutable means we can modify the elements of a series but its size is immutable, i.e. we cannot change the size of the series once declared. It has two main components: data and an index.

# %% [markdown]
# **Pandas DataFrame** is a 2-dimensional data structure that contains elements of the same data. It is mutable, and its size is also mutable, i.e. we can change both data and size of the dataframe data structure. It has labeled axes (rows and columns) and has two different index.
#
# Pandas DataFrame is one of the most used data structure as it closely resembles your excel sheet or excel tabular data type. It is two dimension with rows and columns. Unlike excel where first row numbering starts from 1 the index or numbering of Pandas DataFreame  starts from zero. So first row has index zero, second row has index one and so on. Similarly columns in excel are identified by alphabets as A, B, or AA, AB and so on. Whereas, Pandas DataFrame has columns index similar to row index starting from zero.Rows in tabular data whether excel or Pandas DataFrame generally store observations of individual person, date, incident, product etc. Columns in tabular structure represent attributes or features. Let’s understand this by example, for a DataFrame representing your class, will have features like name of student, roll number of student, section of student etc on columns, whereas rows represent individual observation for a particular student.

# %% [markdown]
# **Common Use Cases of Python Pandas**
#
# 1. Data Cleaning and Preprocessing: Pandas are often used to clean and preprocess messy or incomplete datasets. This involves handling missing values, converting data types, and standardizing formats.
# 2. Data Analysis: Analysts and data scientists use Pandas to explore and analyze data. This includes calculating summary statistics, identifying trends, and creating visualizations.
# 3. Data Visualization: While Pandas itself doesn’t handle visualization, it integrates well with visualization libraries like Matplotlib and Seaborn to create informative graphs and charts.
# 4. Time Series Analysis: Time-based data, such as stock prices, weather data, and sensor readings, can be effectively analyzed and manipulated using Pandas’ time series functionalities.
# 5. Data Merging and Joins: When dealing with multiple datasets, Pandas helps combine and merge data efficiently, even when the data is stored in different formats or has varying structures.
# 6. Feature Engineering: In machine learning workflows, Pandas is used to engineer new features from existing data, preparing the data for model training.
# 7. Data Export and Reporting: After processing and analyzing data, Pandas can be used to export the results back into various formats for reporting or further analysis.

# %% [markdown]
# # **Pandas Install Update & Help**

# %% [markdown]
# Pip is a popular package manager for Python, which allows you to install, upgrade, and manage Python packages.
#
# Pip will be installed with Python by default if you have a later version of Python available (greater than Python 3.5.x).
#
# If you're using an earlier version of Python, you'll need to install pip before you can install Pandas.
#
# The simplest method to install pip is to to update Python to the most recent version found at this link https://www.python.org/

# %%
# install pandas library (not required in colab and anaconda)
# !pip install pandas

# %%
# import library
import pandas as pd

# %%
# check installed version (Double Underscore (Dunder))
pd.__version__
# Out:
# '1.5.3'

# %%
# check installed versions
pd.show_versions()

# %%
# install pandas latest version
# !pip install -U pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 28.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.1.0 which is incompatible.
# ...

# %%
# install specific version
# !pip install pandas==2.1.0

# %%
# help function
help('pandas')
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # **Creating Series and DataFrame**

# %% [markdown]
# ## Creating Series from List

# %%
#importing pandas
import pandas as pd

# %%
#creating  list
data=['Learn','Practice','Upskill','YBI','Foundation']

# %%
#creating pandas series
ds=pd.Series(data)

# %%
#printing series
ds
# Out:
# 0         Learn
# 1      Practice
# 2       Upskill
# 3           YBI
# 4    Foundation
# dtype: object

# %%
# check type of pandas series
type(ds)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Creating Series from List with row index

# %%
#importing pandas
import pandas as pd

# %%
#creating  list
data=['Learn','Practice','Upskill','YBI','Foundation']

# %%
#creating pandas series
ds=pd.Series(data, index=['a','b','c','d','e'])

# %%
#printing series
ds
# Out:
# a         Learn
# b      Practice
# c       Upskill
# d           YBI
# e    Foundation
# dtype: object

# %%
# check type of ds
type(ds)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Creating series from dictionary

# %%
#importing pandas
import pandas as pd

# %%
#creating dictionary
data={'Hindi_Marks':[98,85,90,91,99],
'Sanskrit_Marks':[79,81,93,73,90]}

# %%
#creating series from dictionary
ds=pd.Series(data)

# %%
# printing series
ds
# Out:
#    Hindi_Marks  Sanskrit_Marks
# 0           98              79
# 1           85              81
# 2           90              93
# 3           91              73
# 4           99              90

# %%
# check type of ds
type(ds)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## **Create DataFrame from Dictionary**

# %% [markdown]
# From dictionary key, value, key corresponds to  column name in the resulting DataFrame.

# %%
# import pandas library
import pandas as pd

# %%
# create a dictionary
data = {
    'apples': [3, 2, 0, 1],
    'oranges': [0, 3, 7, 2]
    }

# %%
#creating pandas dataframe
df = pd.DataFrame(data)
df
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# ## **Create DataFrame from Dictionary with row index**

# %%
# use pd.DataFrame with index
df = pd.DataFrame(data, index=['Apr', 'May', 'Jun', 'Jul'])
df
# Out:
#      apples  oranges
# Apr       3        0
# May       2        3
# Jun       0        7
# Jul       1        2

# %% [markdown]
# # **Data Read, Write and Munging**

# %% [markdown]
# Data wrangling, sometimes referred to as data munging, is the process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Read Data as DataFrame

# %% [markdown]
# https://github.com/YBIFoundation/Dataset/raw/main/Titanic.csv

# %%
# import library
import pandas as pd

# %%
# read comma separated value (csv) file
df = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Titanic.csv')

# %% [markdown]
# https://github.com/YBIFoundation/Dataset/raw/main/Gapminder_IRIS.xlsx

# %%
# read excel file
df1 = pd.read_excel('https://github.com/YBIFoundation/Dataset/raw/main/Gapminder_IRIS.xlsx')

# %%
# read excel file with multiple sheet(remember pandas index start from zero)
# read first sheet (its index is zero)
df2 = pd.read_excel('https://github.com/YBIFoundation/Dataset/raw/main/Gapminder_IRIS.xlsx', sheet_name=0)

# %%
# read second sheet (its index is one)
df3 = pd.read_excel('https://github.com/YBIFoundation/Dataset/raw/main/Gapminder_IRIS.xlsx', sheet_name=1)

# %% [markdown]
# ## **Write back (Munging) DataFrame as CSV, Excel, JSON, SQL etc.**

# %%
df.to_csv('new_purchases.csv')

# %%
df.to_excel('new_purchases.xlsx')

# %%
df.to_json('new_purchases.json')

# %% [markdown]
# ## Practice Code

# %% [markdown]
# # **Type Cast**

# %% [markdown]
# # **Explore and View Data**

# %%
# view first five rows
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# view first seven rows
df.head(7)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# ...

# %%
# view last five rows
df.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
# dataframe random smaple
df.sample(3)
# Out:
#       pclass  survived                    name     sex   age  sibsp  parch  \
# 808        3         0        Ford, Mr. Arthur    male   NaN      0      0
# 1075       3         0  Odahl, Mr. Nils Martin    male  23.0      0      0
# 1001       3         1      McCoy, Miss. Agnes  female   NaN      2      0
#
#         ticket    fare cabin embarked boat  body  \
# 808   A/5 1478   8.050   NaN        S  NaN   NaN
# 1075      7267   9.225   NaN        S  NaN   NaN
# 1001    367226  23.250   NaN        Q   16   NaN
#
#                           home.dest
# 808   Bridgwater, Somerset, England
# 1075                            NaN
# 1001                            NaN

# %% [markdown]
# .info() provides the essential details about your dataset, such as the number of rows and columns, the number of non-null values, what type of data is in each column, and how much memory your DataFrame is using.

# %%
# dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# dataframe summary statistics of numerical columns
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
# dataframe summary statistics of all columns
df.describe(include = 'all')
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881138
# std        0.837836     0.486055                   NaN   NaN    14.413493
# min        1.000000     0.000000                   NaN   NaN     0.170000
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %% [markdown]
#  .shape, which outputs just a tuple of (rows, columns)

# %%
# dataframe shape
df.shape
# Out:
# (1309, 14)

# %%
# dataframe columns name

df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %% [markdown]
# # **Selection and Slicing**

# %% [markdown]
# ## **Select Single or Multiple Columns**

# %%
# select single column as series
df['age']
# Out:
# 0       29.00
# 1        0.92
# 2        2.00
# 3       30.00
# 4       25.00
#         ...
# 1304    14.50
# 1305      NaN
# 1306    26.50
# 1307    27.00
# 1308    29.00
# Name: age, Length: 1309, dtype: float64

# %%
# select single column as dataframe
df[['age']]
# Out:
#         age
# 0     29.00
# 1      0.92
# 2      2.00
# 3     30.00
# 4     25.00
# ...     ...
# 1304  14.50
# 1305    NaN
# 1306  26.50
# 1307  27.00
# 1308  29.00
#
# [1309 rows x 1 columns]

# %%
# select multiple columns as dataframe
df[['age','sex']]
# Out:
#         age     sex
# 0     29.00  female
# 1      0.92    male
# 2      2.00  female
# 3     30.00    male
# 4     25.00  female
# ...     ...     ...
# 1304  14.50  female
# 1305    NaN  female
# 1306  26.50    male
# 1307  27.00    male
# 1308  29.00    male
#
# [1309 rows x 2 columns]

# %% [markdown]
# ## .query

# %% [markdown]
# Pandas DataFrame.query() method is used to query the rows based on the expression (single or multiple column conditions) provided and returns a new DataFrame. In case you wanted to update the existing referring DataFrame use inplace=True argument.
#
# You can query the DataFrame using the pandas query() method. A pandas query expression is passed as a string parameter to the pandasquery() method, and it must return True or False. The DataFrame when the result is True by the query statement, is returned.
#
# You can refer to column names that are not valid Python variable names by surrounding them in backticks. Thus, column names containing spaces or punctuations (besides underscores) or starting with digits must be surrounded by backticks. (For example, a column named “Area (cm^2)” would be referenced as `Area (cm^2)`). Column names which are Python keywords (like “list”, “for”, “import”, etc) cannot be used.

# %%
df.query('age>75')
# Out:
#     pclass  survived                                               name  \
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#        sex   age  sibsp  parch ticket   fare cabin embarked boat  body  \
# 14    male  80.0      0      0  27042  30.00   A23        S    B   NaN
# 61  female  76.0      1      0  19877  78.85   C46        S    6   NaN
#
#                   home.dest
# 14            Hessle, Yorks
# 61  Little Onn Hall, Staffs

# %%
df.query("age>75 and sex=='male'")
# Out:
#     pclass  survived                                  name   sex   age  sibsp  \
# 14       1         1  Barkworth, Mr. Algernon Henry Wilson  male  80.0      0
#
#     parch ticket  fare cabin embarked boat  body      home.dest
# 14      0  27042  30.0   A23        S    B   NaN  Hessle, Yorks

# %%
df.query("age>75 and sex=='male'",inplace=True)

# %%
#
df
# Out:
#     pclass  survived                                  name   sex   age  sibsp  \
# 14       1         1  Barkworth, Mr. Algernon Henry Wilson  male  80.0      0
#
#     parch ticket  fare cabin embarked boat  body      home.dest
# 14      0  27042  30.0   A23        S    B   NaN  Hessle, Yorks

# %% [markdown]
# ## **.iloc**

# %%
df.iloc[:]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.iloc[:,:]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ## **.loc**

# %%
df.loc[:]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.loc[:,:]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ## **Boolean Indexing**

# %%
# select where age is not >18
df[~(df['age']>18)]
# Out:
#       pclass  survived                                               name  \
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# ...      ...       ...                                                ...
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex    age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
# select where age is not >18
df[df['age']<=18]
# Out:
#       pclass  survived                                               name  \
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 53         1         0                             Carrau, Mr. Jose Pedro
# 54         1         1                Carter, Master. William Thornton II
# ...      ...       ...                                                ...
# 1275       3         0                    Vander Planke, Mr. Leo Edmondus
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1288       3         0                          Wiklund, Mr. Jakob Alfred
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                               Zabour, Miss. Hileni
#
#          sex    age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
# select where age is between 12 and 18
df[(df['age']>12) & (df['age']<18)]
# Out:
#       pclass  survived                                               name  \
# 53         1         0                             Carrau, Mr. Jose Pedro
# 55         1         1                          Carter, Miss. Lucile Polk
# 92         1         1          Dick, Mrs. Albert Adrian (Vera Gillespie)
# 159        1         1                       Hippach, Miss. Jean Gertrude
# 187        1         1                          Lines, Miss. Mary Conover
# 193        1         1                  Madill, Miss. Georgette Alexandra
# 195        1         1                              Maioni, Miss. Roberta
# 229        1         1  Penasco y Castellana, Mrs. Victor de Satode (M...
# 249        1         1                        Ryerson, Master. John Borie
# 295        1         1                        Thayer, Mr. John Borland Jr
# 350        2         1                          Brown, Miss. Edith Eileen
# 390        2         0                          Deacon, Mr. Percy William
# ...

# %% [markdown]
# # **Data Manipulation**

# %% [markdown]
# ## **Rename Columns**

# %%
 # import the libraries
 import pandas as pd

# read CSV dataset
df = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Admission%20Chance.csv')

# replacing blank spaces with '_'
df.columns =[column.replace(" ", "_") for column in df.columns]

# display
df
# Out:
#      Serial_No  GRE_Score  TOEFL_Score  University_Rating  _SOP  LOR_  CGPA  \
# 0            1        337          118                  4   4.5   4.5  9.65
# 1            2        324          107                  4   4.0   4.5  8.87
# 2            3        316          104                  3   3.0   3.5  8.00
# 3            4        322          110                  3   3.5   2.5  8.67
# 4            5        314          103                  2   2.0   3.0  8.21
# ..         ...        ...          ...                ...   ...   ...   ...
# 395        396        324          110                  3   3.5   3.5  9.04
# 396        397        325          107                  3   3.0   3.5  9.11
# 397        398        330          116                  4   5.0   4.5  9.45
# 398        399        312          103                  3   3.5   4.0  8.78
# 399        400        333          117                  4   5.0   4.0  9.66
#
#      Research  Chance_of_Admit_
# ...

# %% [markdown]
# ## **Duplicate Values**

# %% [markdown]
# ## **Drop Rows or Columns**

# %%
# drop rows
df.drop([0,1,2,3,4], axis=0)
# Out:
#       pclass  survived                                           name     sex  \
# 5          1         1                            Anderson, Mr. Harry    male
# 6          1         1              Andrews, Miss. Kornelia Theodosia  female
# 7          1         0                         Andrews, Mr. Thomas Jr    male
# 8          1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9          1         0                        Artagaveytia, Mr. Ramon    male
# ...      ...       ...                                            ...     ...
# 1304       3         0                           Zabour, Miss. Hileni  female
# 1305       3         0                          Zabour, Miss. Thamine  female
# 1306       3         0                      Zakarian, Mr. Mapriededer    male
# 1307       3         0                            Zakarian, Mr. Ortin    male
# 1308       3         0                             Zimmerman, Mr. Leo    male
#
# ...

# %%
# drop columns
df.drop(['age', 'sex'], axis=1)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %% [markdown]
# ## **Sort Index**

# %%
df.sort_index()
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# ## **Rank**

# %%
df.rank()
# Out:
#       pclass  survived    name    sex    age   sibsp   parch  ticket    fare  \
# 0      162.0    1059.5    22.0  233.5  554.5   446.0   501.5   293.5  1272.5
# 1      162.0    1059.5    24.0  888.0   11.5  1051.0  1229.0    74.5  1260.5
# 2      162.0     405.0    25.0  233.5   28.5  1051.0  1229.0    74.5  1260.5
# 3      162.0     405.0    26.0  888.0  589.5  1051.0  1229.0    74.5  1260.5
# 4      162.0     405.0    27.0  233.5  426.5  1051.0  1229.0    74.5  1260.5
# ...      ...       ...     ...    ...    ...     ...     ...     ...     ...
# 1304   955.0     405.0  1294.0  233.5  108.5  1051.0   501.5   395.5   652.5
# 1305   955.0     405.0  1295.0  233.5    NaN  1051.0   501.5   395.5   652.5
# 1306   955.0     405.0  1296.0  888.0  474.0   446.0   501.5   380.0    65.0
# 1307   955.0     405.0  1297.0  888.0  489.5   446.0   501.5   406.0    65.0
# 1308   955.0     405.0  1298.0  888.0  554.5   446.0   501.5   517.0   276.0
#
# ...

# %% [markdown]
# ## **Sort Data**

# %%
# sort in ascending order
df.sort_values(by=['age'])
# Out:
#       pclass  survived                                     name     sex   age  \
# 763        3         1  Dean, Miss. Elizabeth Gladys "Millvina"  female  0.17
# 747        3         0  Danbom, Master. Gilbert Sigvard Emanuel    male  0.33
# 1240       3         1          Thomas, Master. Assad Alexander    male  0.42
# 427        2         1                Hamalainen, Master. Viljo    male  0.67
# 1111       3         0           Peacock, Master. Alfred Edward    male  0.75
# ...      ...       ...                                      ...     ...   ...
# 1293       3         0        Williams, Mr. Howard Hugh "Harry"    male   NaN
# 1297       3         0                   Wiseman, Mr. Phillippe    male   NaN
# 1302       3         0                        Yousif, Mr. Wazli    male   NaN
# 1303       3         0                    Yousseff, Mr. Gerious    male   NaN
# 1305       3         0                    Zabour, Miss. Thamine  female   NaN
#
# ...

# %%
# sort multiple columns in ascending order
df.sort_values(by=['fare', 'age'])
# Out:
#       pclass  survived                                               name  \
# 898        3         0                    Johnson, Mr. William Cahoone Jr
# 1254       3         1                       Tornquist, Mr. William Henry
# 963        3         0                                Leonard, Mr. Lionel
# 234        1         0                    Reuchlin, Jonkheer. John George
# 7          1         0                             Andrews, Mr. Thomas Jr
# ...      ...       ...                                                ...
# 183        1         1                             Lesurer, Mr. Gustave J
# 302        1         1                                   Ward, Miss. Anna
# 49         1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50         1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 1225       3         0                                 Storey, Mr. Thomas
#
#          sex   age  sibsp  parch    ticket      fare        cabin embarked  \
# ...

# %% [markdown]
# # **Grouping and Sorting**

# %% [markdown]
# # **Merging, Joining, Concatenating**

# %% [markdown]
# # **Missing Data**

# %% [markdown]
# # **Working with Date and Time**

# %% [markdown]
# # **Working With Text Data**

# %% [markdown]
# # **Visualization**

# %% [markdown]
# # **Project: Explore Movie Data**

# %%
# import library
import pandas as pd

# %%
# read data
movie = pd.read_csv('https://github.com/YBIFoundation/Dataset/raw/main/Movies%20Recommendation.csv')

# %%
# view first 5 rows
movie.head()
# Out:
#    Movie_ID      Movie_Title                       Movie_Genre Movie_Language  \
# 0         1       Four Rooms                      Crime Comedy             en
# 1         2        Star Wars  Adventure Action Science Fiction             en
# 2         3     Finding Nemo                  Animation Family             en
# 3         4     Forrest Gump              Comedy Drama Romance             en
# 4         5  American Beauty                             Drama             en
#
#    Movie_Budget  Movie_Popularity Movie_Release_Date  Movie_Revenue  \
# 0       4000000         22.876230         09-12-1995        4300000
# 1      11000000        126.393695         25-05-1977      775398007
# 2      94000000         85.688789         30-05-2003      940335536
# 3      55000000        138.133331         06-07-1994      677945399
# 4      15000000         80.878605         15-09-1999      356296601
#
#    Movie_Runtime  Movie_Vote  ...  \
# 0           98.0         6.5  ...
# ...

# %%
# info
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4760 entries, 0 to 4759
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Movie_ID                  4760 non-null   int64
#  1   Movie_Title               4760 non-null   object
#  2   Movie_Genre               4760 non-null   object
#  3   Movie_Language            4760 non-null   object
#  4   Movie_Budget              4760 non-null   int64
#  5   Movie_Popularity          4760 non-null   float64
#  6   Movie_Release_Date        4760 non-null   object
#  7   Movie_Revenue             4760 non-null   int64
#  8   Movie_Runtime             4758 non-null   float64
#  9   Movie_Vote                4760 non-null   float64
#  10  Movie_Vote_Count          4760 non-null   int64
#  11  Movie_Homepage            1699 non-null   object
#  12  Movie_Keywords            4373 non-null   object
# ...

# %%
# check shape
movie.shape
# Out:
# (4760, 21)

# %%
# check for duplicates
movie[movie.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Movie_ID, Movie_Title, Movie_Genre, Movie_Language, Movie_Budget, Movie_Popularity, Movie_Release_Date, Movie_Revenue, Movie_Runtime, Movie_Vote, Movie_Vote_Count, Movie_Homepage, Movie_Keywords, Movie_Overview, Movie_Production_House, Movie_Production_Country, Movie_Spoken_Language, Movie_Tagline, Movie_Cast, Movie_Crew, Movie_Director]
# Index: []
#
# [0 rows x 21 columns]

# %%
# count duplicates
movie.duplicated().sum()

# %%
# drop duplicates if any
movie.drop_duplicates(inplace=True)

# %%
# rename columns
movie.rename(columns={'Movie_ID':'ID'},inplace=True)

# %%
movie
# Out:
#         ID                  Movie_Title                       Movie_Genre  \
# 0        1                   Four Rooms                      Crime Comedy
# 1        2                    Star Wars  Adventure Action Science Fiction
# 2        3                 Finding Nemo                  Animation Family
# 3        4                 Forrest Gump              Comedy Drama Romance
# 4        5              American Beauty                             Drama
# ...    ...                          ...                               ...
# 4755  4784             Midnight Cabaret                            Horror
# 4756  4785             Growing Up Smith               Comedy Family Drama
# 4757  4786                       8 Days                    Thriller Drama
# 4758  4787              Running Forever                            Family
# 4759  4788  To Be Frank, Sinatra at 100                       Documentary
#
#      Movie_Language  Movie_Budget  Movie_Popularity Movie_Release_Date  \
# ...

# %%
# lowercase all column names

movie.columns = [col.lower() for col in movie]

# %%
movie
# Out:
#         id                  movie_title                       movie_genre  \
# 0        1                   Four Rooms                      Crime Comedy
# 1        2                    Star Wars  Adventure Action Science Fiction
# 2        3                 Finding Nemo                  Animation Family
# 3        4                 Forrest Gump              Comedy Drama Romance
# 4        5              American Beauty                             Drama
# ...    ...                          ...                               ...
# 4755  4784             Midnight Cabaret                            Horror
# 4756  4785             Growing Up Smith               Comedy Family Drama
# 4757  4786                       8 Days                    Thriller Drama
# 4758  4787              Running Forever                            Family
# 4759  4788  To Be Frank, Sinatra at 100                       Documentary
#
#      movie_language  movie_budget  movie_popularity movie_release_date  \
# ...

# %%
# check for missing values
movie.isna().sum()
# Out:
# id                             0
# movie_title                    0
# movie_genre                    0
# movie_language                 0
# movie_budget                   0
# movie_popularity               0
# movie_release_date             0
# movie_revenue                  0
# movie_runtime                  2
# movie_vote                     0
# movie_vote_count               0
# movie_homepage              3061
# movie_keywords               387
# movie_overview                 3
# movie_production_house         0
# movie_production_country       0
# movie_spoken_language          0
# movie_tagline                818
# movie_cast                    27
# movie_crew                     0
# movie_director                22
# dtype: int64

# %%
# drop missing values
movie.dropna(inplace=True)

# %%
# check for missing values
movie.isna().sum()
# Out:
# id                          0
# movie_title                 0
# movie_genre                 0
# movie_language              0
# movie_budget                0
# movie_popularity            0
# movie_release_date          0
# movie_revenue               0
# movie_runtime               0
# movie_vote                  0
# movie_vote_count            0
# movie_homepage              0
# movie_keywords              0
# movie_overview              0
# movie_production_house      0
# movie_production_country    0
# movie_spoken_language       0
# movie_tagline               0
# movie_cast                  0
# movie_crew                  0
# movie_director              0
# dtype: int64

# %%
movie.loc[movie['movie_vote']>=5].count()
# Out:
# id                          1339
# movie_title                 1339
# movie_genre                 1339
# movie_language              1339
# movie_budget                1339
# movie_popularity            1339
# movie_release_date          1339
# movie_revenue               1339
# movie_runtime               1339
# movie_vote                  1339
# movie_vote_count            1339
# movie_homepage              1339
# movie_keywords              1339
# movie_overview              1339
# movie_production_house      1339
# movie_production_country    1339
# movie_spoken_language       1339
# movie_tagline               1339
# movie_cast                  1339
# movie_crew                  1339
# movie_director              1339
# dtype: int64
